# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
csv_path = 'data/Manaus.csv'
df = pd.read_csv(csv_path,encoding='iso-8859-1',sep=';')

# %%
#lista com algumas especificações a serem filtradas
df = df[df._classificacao.eq('Confirmado')]
print("Casos confirmados antes do Filtro: ", len(df.index)) # confirmados antes do filtro

#filterList = ['_comorb', 'sintoma(s)*','_etnia','_profiss_saude','^(_dt_(\w){1,10})$','_origem', '_raca', '_criterio','_srag','_evolução']
#filterList = ['_comorb', 'sintoma(s)*','_etnia','_profiss_saude','^(_dt_(\w){1,10})$','_origem', '_raca', '_criterio','_srag','_evolução','tipo_teste']
for i in range(len(filterList)):
    df = df[df.columns.drop(list(df.filter(regex=filterList[i])))]
    

#observou-se que as colunas com maior numero de NaN em suas células 
# prejudicava a quantidade e qualidade dos dados
#print(df.isnull().mean() * 100)
#df.dropna(inplace=True)


print("1)Total de casos confirmados após os filtros: ", len(df.index)) # o total de dados apos o filtro de dados faltantes são de 68k

print(df['_conclusao'].value_counts())
#print(df.head())
# Out:
# Casos confirmados antes do Filtro:  36947
# 1)Total de casos confirmados após os filtros:  36947
# Recuperado    11340
# Óbito          2040
# Name: _conclusao, dtype: int64

# %%
# print(df_positive['_sexo'].value_counts())

percentRecovered = len(df[df._conclusao.eq('Recuperado')])/len(df.index)
print("2)Porcentagem de individuos recuperados em relação ao todo após os filtros: %.3f" % (percentRecovered*100))

print("3) Masculino: ", len(df[df._sexo.eq('M')]))
print("3) Feminino ", len(df[df._sexo.eq('F')]), "A maior dos casos ocorridos foram do sexo Feminino")

print("4) Média da idade dos Confirmados é: %.3f" %df['_idade'].mean())
print("4) O desvio padrão da idade dos Confirmados é: %.3f" %df['_idade'].std())
print("4) A pessoa mais jovem a contrair tem: ", df['_idade'].min(), "anos, A mais idosa possui: ", df['_idade'].max())


higherRateNeighborhood = df[['_bairro','_taxa']].max()

print("5) O bairro de maior incidencia de casos é: ", higherRateNeighborhood['_bairro'])


higherRecoveredNeighbor = df.groupby(['_bairro','_conclusao'])._conclusao.count().sort_values(ascending=False).iloc[0:3]


print("6) Os bairros com maior incidencia de casos recuperados são: \n", higherRecoveredNeighbor)
# print((higherRecoveredNeighbor[['_conclusao']]
# higherRecoveredNeighbor = higherRecoveredNeighbor[''.max()

# print(higherRecoveredNeighbor)

df.head()#mostra os 5 registros do topo
# Out:
# Casos confirmados antes do Filtro:  36947
# 1)Total de casos confirmados após os filtros:  6214
# Recuperado    6201
# Óbito           13
# Name: _conclusao, dtype: int64
# 2)Porcentagem de individuos recuperados em relação ao todo após os filtros: 99.791
# 3) Masculino:  2707
# 3) Feminino  3507 A maior dos casos ocorridos foram do sexo Feminino
# 4) Média da idade dos Confirmados é: 41.470
# 4) O desvio padrão da idade dos Confirmados é: 14.165
# 4) A pessoa mais jovem a contrair tem:  0.0 anos, A mais idosa possui:  99.0
# 5) O bairro de maior incidencia de casos é:  ZUMBIM DOS PALMARES
# 6) Os bairros com maior incidencia de casos recuperados são:
#  _bairro      _conclusao
# CIDADE NOVA  Recuperado    301
# FLORES       Recuperado    266
# TARUMA       Recuperado    225
# Name: _conclusao, dtype: int64
#        _idade _faixa etária _sexo            _bairro _classificacao  \
# 680      25.0     20a - 29a     F       ADRIANOPOLIS     Confirmado
# 681      41.0     40a - 49a     F            BETANIA     Confirmado
# 67519    40.0     40a - 49a     F          DOM PEDRO     Confirmado
# 67523    50.0     50a - 59a     M             FLORES     Confirmado
# 67540    30.0     30a - 39a     M  PRESIDENTE VARGAS     Confirmado
#
#        _conclusao _dt_notificacao        _taxa               _tipo_teste  \
# 680    Recuperado      20/03/2020   0,99960016                    RT-PCR
# 681    Recuperado      27/03/2020  0,801603206                    RT-PCR
# 67519  Recuperado      20/04/2020  0,483629153  TESTE RÁPIDO - ANTICORPO
# 67523  Recuperado      24/04/2020  0,198306463                    RT-PCR
# 67540  Recuperado      23/04/2020   1,09805644   TESTE RÁPIDO - ANTÍGENO
#
#        _se_notificacao _distrito       _bairro_mapa
# 680               12.0       SUL       ADRIANÓPOLIS
# 681               13.0       SUL            BETÂNIA
# 67519             17.0     OESTE          DOM PEDRO
# 67523             17.0       SUL             FLORES
# 67540             17.0       SUL  PRESIDENTE VARGAS
